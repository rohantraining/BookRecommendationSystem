# %%
from bs4 import BeautifulSoup
import pandas as pd 
import requests
import numpy as np

# %%
def get_title(new_soup):
    try:
        title_string = new_soup.find("span", attrs={"id":'productTitle'}).text.strip()
    except AttributeError:
        title_string = ""
    return title_string

def get_auth(new_soup):
    try:
        auth_string = new_soup.find("span", attrs={"class":'author notFaded'}).text.strip()
        author = auth_string[:auth_string.index('\n')].strip()
    except AttributeError:
        author = ""
    return author

def get_lang(new_soup):
    try:
        language = new_soup.find("div", attrs= {"id":'rpi-attribute-language'}).text.strip()
        lang_string = language[9:].strip()
    except AttributeError:
        lang_string = ""
    return lang_string

def get_publisher(new_soup):
    try:
        pub = new_soup.find("div", attrs={"id":'rpi-attribute-book_details-publisher'}).text.strip()
        pub_string = pub[9:].strip()
    except AttributeError:
        pub_string = ""
    return pub_string

def get_rating(new_soup):
    try:
        rating = new_soup.find("span", attrs={"class":'a-icon-alt'}).text.strip()
        # rat_string = rating[:rating.index("out")]
        if rating == 'Previous page':
            rating = 'Not Available'
    except AttributeError:
        rating = ""
    return rating

# %%
if __name__ == '__main__':
    URL = "https://www.amazon.in/s?k=new+books&i=stripbooks&rh=n%3A976389031%2Cn%3A1318168031&s=review-rank&dc&ds=v1%3A29N7kDSDZTMegHsJ8qkT8bJcVvpKj5vJF0JfxhKIlLQ&crid=29A5CXXO4VDPF&qid=1679839873&rnid=3576079031&sprefix=%2Caps%2C286&ref=sr_st_review-rank"
    HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36 Edg/110.0.1587.69','Accept-Language': 'en-US,en;q=0.5'})
    webpage = requests.get(URL, headers = HEADERS)
    soup = BeautifulSoup(webpage.content, "html.parser")
    links= soup.find_all("a",attrs={'class':'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'})
    
    links_list = []
    for link in links:
       links_list.append(link.get('href'))
    
    image= soup.find_all("img",attrs={"class":'s-image'})
    image
    img_list = []
    for i in image:
        img_list.append(i.get('src'))
   

    d = {"title": [], "author": [], "publisher":[], "rating": [], "language": [], "image_link": []}

    for link in links_list:
        new_webpage = requests.get('https://amazon.com' + link, headers = HEADERS)
        new_soup = BeautifulSoup(new_webpage.content, 'html.parser')

        d['title'].append(get_title(new_soup))
        d['author'].append(get_auth(new_soup))
        d['publisher'].append(get_publisher(new_soup))
        d['rating'].append(get_rating(new_soup))
        d['language'].append(get_lang(new_soup))
    for i in img_list:
        d['image_link'].append(i)

    sem6_df_rom = pd.DataFrame.from_dict(d)
    sem6_df_rom['title'].replace('',np.nan,inplace=True)
    sem6_df_rom = sem6_df_rom.dropna(subset=['title'])
    sem6_df_rom.to_csv("sem6_project_rom.csv", header=True, index = False)

# %%
sem6_df_rom
# Out:
#                                                 title                author  \
# 0   Full Circle (Rollin On Series Early Years Book 3)           Emilia Finn
# 1   Heaven Official's Blessing: Tian Guan Ci Fu (N...     Mo Xiang Tong Xiu
# 2             Rohan at the Louvre (Louvre Collection)        Hirohiko Araki
# 3                   Wotakoi: Love is Hard for Otaku 2                Fujita
# 4   Maid-sama! (2-in-1 Edition), Vol. 1: Includes ...         Hiro Fujiwara
# 5   Fruits Basket Collector's Edition, Vol. 3 (Fru...        Natsuki Takaya
# 6   I Hear the Sunspot: Limit Volume 1 (I Hear the...           Yuki Fumino
# 7   Maid-sama! (2-in-1 Edition), Vol. 2: Includes ...         Hiro Fujiwara
# 8   I Hear the Sunspot: Limit Volume 2 (I Hear the...           Yuki Fumino
# 9   I Hear the Sunspot: Theory of Happiness (I Hea...           Yuki Fumino
# 10                       Yona of the Dawn, Vol. 2 (2)       Mizuho Kusanagi
# ...

# %%
import pickle
import pandas as pd
sem6_df_rom.to_pickle('C:/Users/Admin/Desktop/mp6/Book_recomm/rom.pkl')

  
pickle.dump(sem6_df_rom,open('rom.pkl','wb'))

# %%
if __name__ == '__main__':
    URL = "https://www.amazon.in/s?k=mystery+triller+book&rh=n%3A22960213031&ref=nb_sb_noss"
    HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36 Edg/110.0.1587.69','Accept-Language': 'en-US,en;q=0.5'})
    webpage = requests.get(URL, headers = HEADERS)
    soup = BeautifulSoup(webpage.content, "html.parser")
    links= soup.find_all("a",attrs={'class':'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'})
    
    links_list = []
    for link in links:
       links_list.append(link.get('href'))
    
    image= soup.find_all("img",attrs={"class":'s-image'})
    image
    img_list = []
    for i in image:
        img_list.append(i.get('src'))
   

    d = {"title": [], "author": [], "publisher":[], "rating": [], "language": [], "image_link": []}

    for link in links_list:
        new_webpage = requests.get('https://amazon.com' + link, headers = HEADERS)
        new_soup = BeautifulSoup(new_webpage.content, 'html.parser')

        d['title'].append(get_title(new_soup))
        d['author'].append(get_auth(new_soup))
        d['publisher'].append(get_publisher(new_soup))
        d['rating'].append(get_rating(new_soup))
        d['language'].append(get_lang(new_soup))
    for i in img_list:
        d['image_link'].append(i)

    sem6_df_ms_tr = pd.DataFrame.from_dict(d)
    sem6_df_ms_tr['title'].replace('',np.nan,inplace=True)
    sem6_df_ms_tr = sem6_df_ms_tr.dropna(subset=['title'])
    sem6_df_ms_tr.to_csv("sem6_mystery_triller.csv", header=True, index = False)

# %%
sem6_df_ms_tr
# Out:
#                                                 title                  author  \
# 0                          Ghosts in the Dark Silence           Anita Krishan
# 2                                      Silent Patient        Alex Michaelides
# 4   3 And A Half Murders: An Inspector Saralkar My...             Salil Desai
# 5                                         Dark Matter            Blake Crouch
# 6   The Woman in the Window [Paperback] [Jan 29, 2...              A. J. Finn
# 7                                          That Night          Nidhi Upadhyay
# 8                                   THE GIRLS BENEATH         ARMSTRONG  ROSS
# 9                                      The Guest List              Lucy Foley
# 11                                         That Night          Nidhi Upadhyay
# 12                                        Dead to Her       Pinborough  Sarah
# 13                                  The Wife Upstairs
# ...

# %%
import pickle
import pandas as pd
sem6_df_ms_tr.to_pickle('C:/Users/Admin/Desktop/mp6/Book_recomm/mystery_triller.pkl')

  
pickle.dump(sem6_df_ms_tr,open('mystery_triller.pkl','wb'))

# %%
if __name__ == '__main__':
    URL = "https://www.amazon.in/s?k=literature+and+fiction&rh=n%3A1318157031&ref=nb_sb_noss"
    HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36 Edg/110.0.1587.69','Accept-Language': 'en-US,en;q=0.5'})
    webpage = requests.get(URL, headers = HEADERS)
    soup = BeautifulSoup(webpage.content, "html.parser")
    links= soup.find_all("a",attrs={'class':'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'})
    
    links_list = []
    for link in links:
       links_list.append(link.get('href'))
    
    image= soup.find_all("img",attrs={"class":'s-image'})
    image
    img_list = []
    for i in image:
        img_list.append(i.get('src'))
   

    d = {"title": [], "author": [], "publisher":[], "rating": [], "language": [], "image_link": []}

    for link in links_list:
        new_webpage = requests.get('https://amazon.com' + link, headers = HEADERS)
        new_soup = BeautifulSoup(new_webpage.content, 'html.parser')

        d['title'].append(get_title(new_soup))
        d['author'].append(get_auth(new_soup))
        d['publisher'].append(get_publisher(new_soup))
        d['rating'].append(get_rating(new_soup))
        d['language'].append(get_lang(new_soup))
    for i in img_list:
        d['image_link'].append(i)

    sem6_lit_fic = pd.DataFrame.from_dict(d)
    sem6_lit_fic['title'].replace('',np.nan,inplace=True)
    sem6_lit_fic = sem6_lit_fic.dropna(subset=['title'])
    sem6_lit_fic.to_csv("sem6_literature_fiction.csv", header=True, index = False)

# %%
sem6_lit_fic
# Out:
#                                                 title                  author  \
# 2   The Cambridge Companion to Gothic Fiction (Cam...        Jerrold E. Hogle
# 3   Contemporary Fiction (Cambridge Contexts in Li...          Pamela Bickley
# 4   The Cambridge Companion to Science Fiction (Ca...            Edward James
# 5   The Cambridge Companion to World Crime Fiction...          Jesper Gulddal
# 6   Contemporary American Literature Poetry, Ficti...          Ed. R. Bhongle
# 7   The Cambridge Companion to Postmodern American...              Paula Geyh
# 8   Sybil or the Two Nations: A tale of romanticis...       Benjamin Disraeli
# 10                                              Antra                 Sukhjit
# 18                      Taxi Wallah and Other Stories  Numair At if Choudhury
# 19                                 English Literature         William J. Long
#
#                        publisher              rating language  \
# ...

# %%
import pickle
import pandas as pd
sem6_lit_fic.to_pickle('C:/Users/Admin/Desktop/mp6/Book_recomm/literature_fiction.pkl')

  
pickle.dump(sem6_lit_fic,open('literature_fiction.pkl','wb'))

# %%
if __name__ == '__main__':
    URL = "https://www.amazon.in/s?k=engineering&rh=n%3A22960344031&ref=nb_sb_noss"
    HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36 Edg/110.0.1587.69','Accept-Language': 'en-US,en;q=0.5'})
    webpage = requests.get(URL, headers = HEADERS)
    soup = BeautifulSoup(webpage.content, "html.parser")
    links= soup.find_all("a",attrs={'class':'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'})
    
    links_list = []
    for link in links:
       links_list.append(link.get('href'))
    
    image= soup.find_all("img",attrs={"class":'s-image'})
    image
    img_list = []
    for i in image:
        img_list.append(i.get('src'))
   

    d = {"title": [], "author": [], "publisher":[], "rating": [], "language": [], "image_link": []}

    for link in links_list:
        new_webpage = requests.get('https://amazon.com' + link, headers = HEADERS)
        new_soup = BeautifulSoup(new_webpage.content, 'html.parser')

        d['title'].append(get_title(new_soup))
        d['author'].append(get_auth(new_soup))
        d['publisher'].append(get_publisher(new_soup))
        d['rating'].append(get_rating(new_soup))
        d['language'].append(get_lang(new_soup))
    for i in img_list:
        d['image_link'].append(i)

    sem6_eng = pd.DataFrame.from_dict(d)
    sem6_eng['title'].replace('',np.nan,inplace=True)
    sem6_eng = sem6_eng.dropna(subset=['title'])
    sem6_eng.to_csv("sem6_engineering_book.csv", header=True, index = False)

# %%
sem6_eng
# Out:
#                                                 title  \
# 0   MECHANICAL ENGINEERING (CONVENTIONAL AND OBJEC...
# 3   MECHANICAL ENGINEERING (CONVENTIONAL AND OBJEC...
# 5   Civil Engineering: Through Objective Type Ques...
# 7               Foundations Of Electrical Engineering
# 9   Civil Engineering: Conventional and Objective ...
# 10                             Automobile Engineering
# 11                     Energy Harvesting Technologies
# 12  CIVIL ENGINEERING THROUGH OBJECTIVE TYPE QUEST...
# 13  Conventional & Objective Type Questions & Answ...
# 14                  A Textbook of Engineering Physics
# 15  ENVIRONMENTAL ENGINEERING : SEWAGE DISPOSAL AN...
# 16  Water Supply Engineering: Environmental Engine...
# 17  Estimating and Costing in Civil Engineering: T...
# 18          Engineering Circuit Analysis, 9th Edition
# 19   Industrial Engineering and Production Management
# 20                             Irrigation Engineering
# ...

# %%
import pickle
import pandas as pd
sem6_eng.to_pickle('C:/Users/Admin/Desktop/mp6/Book_recomm/engineering.pkl')

  
pickle.dump(sem6_eng,open('engineering.pkl','wb'))

# %%
if __name__ == '__main__':
    URL = "https://www.amazon.in/s?k=manga+books&crid=NSSPBUN1DJ9T&sprefix=manga%2Caps%2C656&ref=nb_sb_ss_ts-doa-p_1_5"
    HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36 Edg/110.0.1587.69','Accept-Language': 'en-US,en;q=0.5'})
    webpage = requests.get(URL, headers = HEADERS)
    soup = BeautifulSoup(webpage.content, "html.parser")
    links= soup.find_all("a",attrs={'class':'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'})
    
    links_list = []
    for link in links:
       links_list.append(link.get('href'))
    
    image= soup.find_all("img",attrs={"class":'s-image'})
    image
    img_list = []
    for i in image:
        img_list.append(i.get('src'))
   

    d = {"title": [], "author": [], "publisher":[], "rating": [], "language": [], "image_link": []}

    for link in links_list:
        new_webpage = requests.get('https://amazon.com' + link, headers = HEADERS)
        new_soup = BeautifulSoup(new_webpage.content, 'html.parser')

        d['title'].append(get_title(new_soup))
        d['author'].append(get_auth(new_soup))
        d['publisher'].append(get_publisher(new_soup))
        d['rating'].append(get_rating(new_soup))
        d['language'].append(get_lang(new_soup))
    for i in img_list:
        d['image_link'].append(i)

    sem6_manga = pd.DataFrame.from_dict(d)
    sem6_manga['title'].replace('',np.nan,inplace=True)
    sem6_manga = sem6_manga.dropna(subset=['title'])
    sem6_manga.to_csv("sem6_japanese_manga.csv", header=True, index = False)

# %%
sem6_manga
# Out:
#                                                 title  \
# 0                             Attack on Titan Sampler
# 1                      Naruto, Vol. 1: Uzumaki Naruto
# 3   The New Married Life Volume: 1 (Well manga Boo...
# 5                              Attack on Titan Vol. 1
# 6   Naruto (3-in-1 Edition), Vol. 3: Includes vols...
# 7   A Silent Voice 1 (A Silent Voice Complete Seri...
# 9        Demon Slayer: Kimetsu no Yaiba, Vol. 15 (15)
# 10  Color BTS! The Most Beautiful BTS Coloring Boo...
# 11                                             Always
# 12  Manga Comedy: The Best Dank Joke Book XL 2023 ...
# 13  How to Draw Manga: How to Draw Anime Book for ...
# 14                            Tokyo Ghoul, Vol. 1 (1)
# 15                    Death Note (All-in-One Edition)
# 17  Attack on Titan Season 1 Part 1 Manga Box Set ...
# 18                 Shine of the Moon: A Graphic Novel
# 19  My Awesome Comic Book: Write and Illustrate Yo...
#
# ...

# %%
import pickle
import pandas as pd
sem6_manga.to_pickle('C:/Users/Admin/Desktop/mp6/Book_recomm/manga.pkl')

  
pickle.dump(sem6_manga,open('manga.pkl','wb'))
